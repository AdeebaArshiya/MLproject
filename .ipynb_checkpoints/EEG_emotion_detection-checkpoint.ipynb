# %%
# !pip install kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaggle in c:\users\adeeb\appdata\roaming\python\python313\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (2025.10.5)
# Requirement already satisfied: charset-normalizer in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (3.4.3)
# Requirement already satisfied: idna in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (6.32.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\users\adeeb\appdata\roaming\python\python313\site-packages (from tqdm->kaggle) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kaggle
kaggle.api.authenticate()

# %%
import os
os.makedirs('./eeg_data', exist_ok=True)

# %%
kaggle.api.dataset_download_files(
    'birdy654/eeg-brainwave-dataset-feeling-emotions',
    path='./eeg_data',
    unzip=True
)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/birdy654/eeg-brainwave-dataset-feeling-emotions

# %%
import os
files = os.listdir('./eeg_data')
print(files)
# Out:
# ['emotions.csv']

# %%
import pandas as pd

df = pd.read_csv('./eeg_data/emotions.csv')

print(df.head())
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
#    fft_744_b  fft_745_b  fft_746_b  fft_747_b  fft_748_b  fft_749_b     label
# 0       23.5     -215.0     280.00    -162.00    -162.00     280.00  NEGATIVE
# 1      -23.3      182.0       2.57     -31.60     -31.60       2.57   NEUTRAL
# 2      462.0     -267.0     281.00    -148.00    -148.00     281.00  POSITIVE
# 3      299.0      132.0     -12.40       9.53       9.53     -12.40  POSITIVE
# 4       12.0      119.0     -17.60      23.90      23.90     -17.60   NEUTRAL
#
# [5 rows x 2549 columns]

# %%
print(df['label'].value_counts())
# Out:
# label
# NEUTRAL     716
# NEGATIVE    708
# POSITIVE    708
# Name: count, dtype: int64

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (2132, 2549)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2132 entries, 0 to 2131
# Columns: 2549 entries, # mean_0_a to label
# dtypes: float64(2548), object(1)
# memory usage: 41.5+ MB
# None
#         # mean_0_a     mean_1_a     mean_2_a     mean_3_a     mean_4_a  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000
# mean     15.256914    27.012462  -104.975629    13.605898    24.150483
# std      15.284621     9.265141   206.271960    16.874676    14.187340
# min     -61.300000  -114.000000  -970.000000  -137.000000  -217.000000
# 25%       6.577500    26.075000  -195.000000     4.857500    23.600000
# 50%      14.100000    30.000000    14.950000    15.400000    25.200000
# 75%      27.700000    31.400000    29.600000    26.500000    26.800000
# max     304.000000    42.300000   661.000000   206.000000   213.000000
#
#         mean_d_0_a   mean_d_1_a   mean_d_2_a   mean_d_3_a   mean_d_4_a  ...  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000  ...
# mean      0.025378     0.052282     0.301655     0.036793     0.083567  ...
# std      17.981796     8.509174    68.098894    17.010031    18.935378  ...
# min    -218.000000  -255.000000 -1360.000000  -203.000000  -553.000000  ...
# 25%      -3.105000    -1.340000    -4.002500    -2.905000    -2.622500  ...
# 50%      -0.044600     0.132000     0.957500    -0.099750     0.146500  ...
# 75%       2.920000     1.540000     6.735000     2.535000     2.870000  ...
# max     402.000000   257.000000  1150.000000   349.000000   444.000000  ...
#
#          fft_740_b    fft_741_b    fft_742_b    fft_743_b    fft_744_b  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000
# mean    -22.938971   104.946111   -51.973647   -51.973647   104.946111
# std     298.034311   212.532721   112.160233   112.160233   212.532721
# min   -1180.000000  -921.000000  -504.000000  -504.000000  -921.000000
# 25%    -106.500000    -8.365000   -92.900000   -92.900000    -8.365000
# 50%      83.850000    12.150000   -21.800000   -21.800000    12.150000
# 75%     154.000000   177.000000    12.025000    12.025000   177.000000
# max    1070.000000   843.000000  1490.000000  1490.000000   843.000000
#
#          fft_745_b    fft_746_b    fft_747_b    fft_748_b    fft_749_b
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000
# mean     -6.934144    95.104886   -49.061255   -49.061255    95.104886
# std     281.040552   203.194976   106.486317   106.486317   203.194976
# min   -1160.000000 -1010.000000  -521.000000  -521.000000 -1010.000000
# 25%    -102.500000    -8.837500   -87.150000   -87.150000    -8.837500
# 50%      89.700000    13.400000   -24.100000   -24.100000    13.400000
# 75%     153.000000   149.250000    10.925000    10.925000   149.250000
# max    1180.000000   888.000000  1670.000000  1670.000000   888.000000
#
# [8 rows x 2548 columns]

# %%
# Create mapping from original labels to your emotions
emotion_mapping = {
    'NEUTRAL': 'calm',
    'POSITIVE': 'Excited',
    'NEGATIVE': 'Stress'
}

# Add new column with mapped emotions
df['emotion'] = df['label'].map(emotion_mapping)

# Check the result
print(df['emotion'].value_counts())
# Out:
# emotion
# calm       716
# Stress     708
# Excited    708
# Name: count, dtype: int64

# %%
# Check missing values
print("Missing values per column:")
print(df.isnull().sum())

# Remove rows with missing values
df_clean = df.dropna()

print(f"\nOriginal shape: {df.shape}")
print(f"After removing missing values: {df_clean.shape}")
print(f"Rows removed: {df.shape[0] - df_clean.shape[0]}")
# Out:
# Missing values per column:
# # mean_0_a    0
# mean_1_a      0
# mean_2_a      0
# mean_3_a      0
# mean_4_a      0
#              ..
# fft_747_b     0
# fft_748_b     0
# fft_749_b     0
# label         0
# emotion       0
# Length: 2550, dtype: int64
#
# Original shape: (2132, 2550)
# After removing missing values: (2132, 2550)
# Rows removed: 0

# %%
# Remove rows where any EEG value is > 50 (threshold)
X = df.drop(['label', 'emotion'], axis=1)
df_clean = df[(X.abs() < 50).all(axis=1)]

print(f"Removed {len(df) - len(df_clean)} artifacts")
# Out:
# Removed 2132 artifacts

# %%
# Check current state
print("Current shape:", df_clean.shape)
print("Rows:", len(df_clean))

# If empty, reload the data
if len(df_clean) == 0:
    print("Data is empty! Reloading...")
    df_clean = df.copy()
    print("Reloaded shape:", df_clean.shape)
# Out:
# Current shape: (0, 2550)
# Rows: 0
# Data is empty! Reloading...
# Reloaded shape: (2132, 2550)

# %%
print(df_clean.columns)
# Out:
# Index(['# mean_0_a', 'mean_1_a', 'mean_2_a', 'mean_3_a', 'mean_4_a',
#        'mean_d_0_a', 'mean_d_1_a', 'mean_d_2_a', 'mean_d_3_a', 'mean_d_4_a',
#        ...
#        'fft_742_b', 'fft_743_b', 'fft_744_b', 'fft_745_b', 'fft_746_b',
#        'fft_747_b', 'fft_748_b', 'fft_749_b', 'label', 'emotion'],
#       dtype='object', length=2550)

# %%
print(df_clean.head())
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_742_b  fft_743_b  fft_744_b  \
# 0      -15.70        2.06        3.15  ...       20.3       20.3       23.5
# 1        2.88        3.83       -4.82  ...      -21.8      -21.8      -23.3
# 2       90.20       89.90        2.03  ...     -233.0     -233.0      462.0
# 3        8.82        2.30       -1.97  ...     -243.0     -243.0      299.0
# 4        3.06       41.40        5.52  ...       38.1       38.1       12.0
#
#    fft_745_b  fft_746_b  fft_747_b  fft_748_b  fft_749_b     label  emotion
# 0     -215.0     280.00    -162.00    -162.00     280.00  NEGATIVE   Stress
# 1      182.0       2.57     -31.60     -31.60       2.57   NEUTRAL     calm
# 2     -267.0     281.00    -148.00    -148.00     281.00  POSITIVE  Excited
# 3      132.0     -12.40       9.53       9.53     -12.40  POSITIVE  Excited
# 4      119.0     -17.60      23.90      23.90     -17.60   NEUTRAL     calm
#
# [5 rows x 2550 columns]

# %%
from sklearn.preprocessing import StandardScaler
# Separate features and labels
X = df_clean.drop(['label', 'emotion'], axis=1)
y = df_clean['emotion']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Features scaled!")
print(f"Feature shape: {X_scaled.shape}")
print(f"Labels shape: {y.shape}")
# Out:
# Features scaled!
# Feature shape: (2132, 2548)
# Labels shape: (2132,)

# %%
from sklearn.preprocessing import StandardScaler

# Prepare features and labels
# Select only Alpha, Beta, Gamma columns
X = df_clean[['mean_3_a', 'mean_4_a', '# mean_0_a']]
y = df_clean['emotion']


# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Create and fit the label encoder on all labels y (not just y_train)
le = LabelEncoder()
le.fit(y)

# Transform train and test labels to integers
y_train_enc = le.transform(y_train)
y_test_enc = le.transform(y_test)

# Train SVM using encoded integer labels
svm_model = SVC(kernel='rbf', random_state=42)
svm_model.fit(X_train, y_train_enc)

# Predict on test set
y_pred_enc = svm_model.predict(X_test)

# Evaluate predictions (using encoded labels)
acc = accuracy_score(y_test_enc, y_pred_enc)
print(f"Test accuracy: {acc:.2f}")
print(classification_report(y_test_enc, y_pred_enc, target_names=le.classes_))
# Out:
# Test accuracy: 0.89
#               precision    recall  f1-score   support
#
#      Excited       0.86      0.88      0.87       136
#       Stress       0.86      0.83      0.84       143
#         calm       0.95      0.95      0.95       148
#
#     accuracy                           0.89       427
#    macro avg       0.89      0.89      0.89       427
# weighted avg       0.89      0.89      0.89       427

# %%
for i in range(10):
    x = X_test[i].reshape(1, -1)
    y_true = le.inverse_transform([y_test_enc[i]])[0]
    y_pred = le.inverse_transform(model.predict(x))[0]
    print(f"True: {y_true} - Predicted: {y_pred}")
# Out:
# True: calm - Predicted: calm
# True: calm - Predicted: calm
# True: Stress - Predicted: Stress
# True: Stress - Predicted: Stress
# True: Excited - Predicted: Excited
# True: calm - Predicted: calm
# True: Stress - Predicted: Stress
# True: Excited - Predicted: Stress
# True: Excited - Predicted: Excited
# True: Stress - Predicted: Stress

# %%
from sklearn.model_selection import cross_val_score

# Perform 5-fold cross-validation
scores = cross_val_score(svm_model, X_train, y_train, cv=5, scoring='accuracy')

print(f"Cross-validation accuracy scores: {scores}")
print(f"Mean CV accuracy: {scores.mean():.2f}")
print(f"Std Dev: {scores.std():.2f}")
# Out:
# Cross-validation accuracy scores: [0.88856305 0.90615836 0.8797654  0.89442815 0.90029326]
# Mean CV accuracy: 0.89
# Std Dev: 0.01

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import joblib
joblib.dump(svm_model, 'eeg_model.pkl')       # Save the trained model
joblib.dump(scaler, 'scaler.pkl')             # Save the fitted scaler
joblib.dump(le, 'label_encoder.pkl')          # Save the fitted label encoder
# Out:
# ['label_encoder.pkl']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)  # Fit scaler on training data before saving

import joblib
joblib.dump(scaler, 'scaler.pkl')  # Save the fitted scaler
# Out:
# ['scaler.pkl']

# %%
import numpy as np
print(np.unique(y_train, return_counts=True))
# Out:
# (array(['Excited', 'Stress', 'calm'], dtype=object), array([572, 565, 568]))

# %%
sample_input = X_test[0].reshape(1, -1)
print("Sample input:", sample_input)
print("Predicted label:", le.inverse_transform(svm_model.predict(sample_input))[0])
# Out:
# Sample input: [[0.82949061 0.06694276 1.00406054]]
# Predicted label: calm

# %%
for i in range(len(y_test_enc)):
    label = le.inverse_transform([y_test_enc[i]])[0]
    if label == "calm":
        print("calm sample:", X_test[i])
    # Repeat for "Excited" and "Stress"
# Out:
# calm sample: [0.82949061 0.06694276 1.00406054]
# calm sample: [ 0.80578089 -0.06701088  0.90589965]
# calm sample: [0.63388542 0.08809333 0.63759324]
# calm sample: [0.79392603 0.01759142 0.91898777]
# calm sample: [ 0.7879986  -0.16571355  0.86009124]
# calm sample: [ 0.82356318 -0.01765954  0.84700313]
# calm sample: [1.11400726 0.14449486 0.93861995]
# calm sample: [0.82949061 0.29959907 1.06295707]
# calm sample: [ 0.72279687 -0.03175992  0.84700313]
# calm sample: [ 0.74057916 -0.00355916  0.85354718]
# calm sample: [0.73465173 0.01054123 0.87317936]
# calm sample: [0.82356318 0.10219371 0.95170807]
# calm sample: [0.68130486 0.10219371 0.78156254]
# calm sample: [0.81763575 0.03874199 0.81428283]
# calm sample: [ 0.91840206 -0.08111126  1.04986895]
# calm sample: [0.49755453 0.10219371 0.61141701]
# calm sample: [0.82356318 0.13039448 0.87317936]
# calm sample: [ 0.76428888 -0.02470973  0.82737095]
# calm sample: [0.7879986  0.13039448 0.84700313]
# calm sample: [ 1.03102323 -0.08816145  1.10222142]
# calm sample: [ 0.98360379 -0.01060935  1.06295707]
# calm sample: [0.81763575 0.15859524 0.87972342]
# calm sample: [0.84134547 0.0316918  0.93861995]
# calm sample: [0.83541804 0.20089639 0.87317936]
# calm sample: [0.89469234 0.06694276 0.95825212]
# calm sample: [ 0.74650659 -0.03881011  0.81428283]
# calm sample: [0.83541804 0.08104314 1.01714865]
# calm sample: [0.52126425 0.02464161 0.63759324]
# calm sample: [0.78207117 0.08809333 0.72921007]
# calm sample: [0.85912776 0.08104314 0.99097242]
# calm sample: [0.89469234 0.06694276 0.96479618]
# calm sample: [0.82949061 0.08104314 0.93207589]
# calm sample: [1.30368502 0.22204696 1.40979218]
# calm sample: [ 0.79985346 -0.11636222  0.76847442]
# calm sample: [2.19872696 0.01054123 2.38485694]
# calm sample: [0.88283748 0.01759142 0.98442836]
# calm sample: [0.97174893 0.09514352 1.01060459]
# calm sample: [ 0.91840206 -0.05291049  1.03023677]
# calm sample: [ 0.94803921 -0.10931202  1.05641301]
# calm sample: [0.82356318 0.13039448 0.80119471]
# calm sample: [0.82949061 0.14449486 1.03678083]
# calm sample: [-0.62687896  0.09514352 -0.75432806]
# calm sample: [ 1.05473295 -0.05996069  0.96479618]
# calm sample: [0.7879986  0.05989256 0.90589965]
# calm sample: [-0.16631764  0.12334429 -0.16732599]
# calm sample: [ 1.01916837 -0.05291049  1.12185359]
# calm sample: [0.73465173 0.02464161 0.81428283]
# calm sample: [ 1.0250958  -0.09521164  1.27891101]
# calm sample: [0.97174893 0.02464161 0.82082689]
# calm sample: [0.74650659 0.01759142 0.84045907]
# calm sample: [1.00138608 0.14449486 1.15457389]
# calm sample: [0.8472729  0.01759142 0.97134024]
# calm sample: [0.93025692 0.12334429 1.04986895]
# calm sample: [1.00138608 0.15859524 1.31817536]
# calm sample: [0.7879986  0.08809333 0.87972342]
# calm sample: [ 0.9065472  -0.09521164  0.97134024]
# calm sample: [ 0.87098262 -0.12341241  1.04986895]
# calm sample: [ 0.83541804 -0.08111126  0.95825212]
# calm sample: [-0.04184161  0.09514352  0.02245172]
# calm sample: [0.91840206 0.23614734 0.65722542]
# calm sample: [0.62795799 0.17974581 0.74884224]
# calm sample: [ 0.70501458 -0.02470973  0.79465065]
# calm sample: [0.72279687 0.08104314 0.7553863 ]
# calm sample: [ 0.85912776 -0.10931202  0.79465065]
# calm sample: [ 0.82949061 -0.01060935  0.82082689]
# calm sample: [0.66945    0.00349104 1.02369271]
# calm sample: [ 0.76428888 -0.09521164  0.80119471]
# calm sample: [1.10807983 0.05284237 1.24619071]
# calm sample: [0.72279687 0.1092439  0.71612195]
# calm sample: [0.81763575 0.22909715 0.92553183]
# calm sample: [0.79985346 0.05989256 0.81428283]
# calm sample: [0.74057916 0.15859524 0.7881066 ]
# calm sample: [ 0.91840206 -0.12341241  1.13494171]
# calm sample: [ 0.84134547 -0.03175992  0.82737095]
# calm sample: [0.8472729  0.09514352 0.9778843 ]
# calm sample: [0.68723229 0.13039448 0.65722542]
# calm sample: [-0.07740619  0.05989256  0.0093636 ]
# calm sample: [ 0.87098262 -0.05996069  0.8993556 ]
# calm sample: [0.89469234 0.10219371 0.93207589]
# calm sample: [ 0.81763575 -0.07406107  0.8993556 ]
# calm sample: [1.65933082 0.14449486 1.92677283]
# calm sample: [0.56275626 0.08104314 0.6441373 ]
# calm sample: [ 0.69315972 -0.03175992  0.70303383]
# calm sample: [0.81170832 0.13039448 0.80119471]
# calm sample: [ 0.80578089 -0.05291049  0.8993556 ]
# calm sample: [0.81763575 0.12334429 0.9778843 ]
# calm sample: [ 1.52299993 -0.15866336  1.69118671]
# calm sample: [0.79392603 0.08809333 0.84700313]
# calm sample: [ 0.78207117 -0.03175992  0.85354718]
# calm sample: [0.68130486 0.07399295 0.74229818]
# calm sample: [0.82949061 0.23614734 0.7553863 ]
# calm sample: [0.8472729  0.18679601 0.93207589]
# calm sample: [ 0.50940939 -0.08111126  0.57215266]
# calm sample: [0.70501458 0.01054123 0.84700313]
# calm sample: [ 0.63388542 -0.08816145  0.70957789]
# calm sample: [0.91840206 0.17974581 0.99097242]
# calm sample: [ 0.90061977 -0.01765954  1.10876548]
# calm sample: [1.66525825 0.0316918  1.98566935]
# calm sample: [0.73465173 0.02464161 0.90589965]
# calm sample: [0.80578089 0.11629409 0.8993556 ]
# calm sample: [ 0.93025692 -0.05996069  0.99097242]
# calm sample: [0.90061977 0.10219371 0.91244371]
# calm sample: [ 0.9065472  -0.01765954  1.02369271]
# calm sample: [ 0.75243402 -0.02470973  0.81428283]
# calm sample: [ 0.50940939 -0.0458603   0.59178483]
# calm sample: [ 1.52892736 -0.11636222  1.74353918]
# calm sample: [ 0.88283748 -0.10931202  0.97134024]
# calm sample: [ 0.64574028 -0.10226183  0.7553863 ]
# calm sample: [0.83541804 0.0316918  0.95825212]
# calm sample: [1.03695066 0.09514352 1.11530954]
# calm sample: [0.84134547 0.06694276 0.94516401]
# calm sample: [-0.45083428 -0.01060935 -0.49256571]
# calm sample: [0.91840206 0.09514352 0.92553183]
# calm sample: [ 0.04114241 -0.03175992 -0.10842946]
# calm sample: [0.97767636 0.01054123 1.09567736]
# calm sample: [ 0.68130486 -0.29966719  0.80773877]
# calm sample: [ 0.77021631 -0.0458603   0.74884224]
# calm sample: [0.91247463 0.11629409 0.95825212]
# calm sample: [0.93025692 0.0316918  1.03023677]
# calm sample: [0.70501458 0.25729792 0.85354718]
# calm sample: [0.80578089 0.08809333 0.89281154]
# calm sample: [ 1.03695066 -0.08816145  1.14148577]
# calm sample: [0.87098262 0.12334429 1.00406054]
# calm sample: [ 0.67537743 -0.05996069  0.74229818]
# calm sample: [0.62203056 0.07399295 0.65068136]
# calm sample: [0.75836145 0.11629409 0.63759324]
# calm sample: [ 0.9658215  -0.17981394  0.92553183]
# calm sample: [ 1.07844267 -0.01060935  1.12839765]
# calm sample: [ 0.75243402 -0.11636222  0.87317936]
# calm sample: [0.72279687 0.08104314 0.80773877]
# calm sample: [ 0.95396664 -0.08111126  0.96479618]
# calm sample: [ 0.75836145 -0.15161317  0.83391501]
# calm sample: [0.82356318 0.00349104 0.86009124]
# calm sample: [ 0.94803921 -0.02470973  1.01060459]
# calm sample: [ 0.58053855 -0.11636222  0.6441373 ]
# calm sample: [0.88283748 0.13039448 0.88626748]
# calm sample: [ 0.94211178 -0.03175992  0.91898777]
# calm sample: [ 0.84134547 -0.16571355  0.88626748]
# calm sample: [ 0.90061977 -0.01765954  0.9778843 ]
# calm sample: [0.9065472  0.32074964 1.01060459]
# calm sample: [0.69315972 0.11629409 0.70303383]
# calm sample: [0.74057916 0.22204696 0.81428283]
# calm sample: [0.95396664 0.02464161 1.00406054]
# calm sample: [-0.21610805  0.25024773 -0.20004628]
# calm sample: [0.85912776 0.1092439  1.03678083]
# calm sample: [ 0.8472729  -0.08111126  0.8993556 ]
# calm sample: [0.70501458 0.21499677 0.81428283]
# calm sample: [0.79392603 0.01054123 0.74884224]

# %%
import numpy as np

# Find average ranges per class
for emotion in ['Excited', 'Stress', 'calm']:
    indexes = [i for i, label in enumerate(le.inverse_transform(y_train_enc)) if label == emotion]
    print(f"{emotion} alpha mean: {np.mean(X_train[indexes, 0])}")
    print(f"{emotion} beta mean: {np.mean(X_train[indexes, 1])}")
    print(f"{emotion} gamma mean: {np.mean(X_train[indexes, 2])}")
# Out:
# Excited alpha mean: -0.6583005753699007
# Excited beta mean: -0.22987892132627383
# Excited gamma mean: -0.5445772139570428
# Stress alpha mean: -0.14191967778230752
# Stress beta mean: 0.2119820343501906
# Stress gamma mean: -0.3256945153784956
# calm alpha mean: 0.8191270009873632
# calm beta mean: 0.03725251407066293
# calm gamma mean: 0.891947444328126

# %%
print("Scaler means:", scaler.mean_)
print("Scaler stds:", scaler.scale_)
# Out:
# Scaler means: [0.00500386 0.0055358  0.00651647]
# Scaler stds: [1.0210069  1.04218306 1.02454405]
